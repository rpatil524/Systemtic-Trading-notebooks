# %% [markdown]
# # Futures long-only performance summary
#
# This notebook summarises long-only performance statistics for major futures contracts provided by various data sources. Daily returns are computed by rolling the front contract before either the first notice day or the last trade day to avoid deliveries. Concretely, a daily return on a given day is written as follows:
#
# $$
# r_{t, i} = \frac{F_{t, i} - F_{t-1, t}}{F_{rolldate, i}}
# $$
#
# where $F_{t, i}$ is the futures price at time $t$ for an instrument $i$, $F_{rolldate, i}$ is the futures price when we roll into the contract. All functionalities as well as underlying data are provided by a private library `vivace`.

# %%
from datetime import datetime
import logging
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import pytz
import matplotlib.pyplot as plt
plt.style.use('bmh')

from vivace.backtest.contract import all_futures_lo_map
from vivace.backtest.engine import BacktestEngine
from vivace.backtest.stats import Performance, PerfStats
from vivace.enums import Strategy

# %% [markdown]
# `all_futures_lo_map` contains the list of all available futures contracts for long-only calculation.

# %%
all_futures_lo_map
# Out:
# ticker
# AC            MSCI World
# AD     Australian Dollar
# AE                   AEX
# AP               SPI 200
# B8     CZCE Ferrosilicon
#              ...
# YQ       DCE Coking Coal
# YY          DCE Iron Ore
# Z               FTSE 100
# ZB    New Zealand Dollar
# ZO                  Oats
# Name: name, Length: 168, dtype: object

# %% [markdown]
# Without any signals, `BacktestEngine` calculates simple long-only strategies by default. `Performance` computes typical performance metrics such as Sharpe ratio.

# %%
results = []

for ticker, name in all_futures_lo_map.items():
    engine = BacktestEngine(
        instrument=ticker,
        strategy=Strategy.DELTA_ONE.value,
        log_level=logging.WARNING,
    )
    engine.run()
    equity_curve = engine.calculate_equity_curve(calculate_net=False)
    stats = Performance(equity_curve).summary().squeeze()
    
    results.append([
        name,
        equity_curve.index[0].strftime('%d-%b-%Y'),
        equity_curve.index[-1].strftime('%d-%b-%Y'),
        stats[PerfStats.CAGR.value],
        stats[PerfStats.ANN_VOL.value],
        stats[PerfStats.SHARPE.value],
        stats[PerfStats.SKEWNESS.value],
    ])
    
result = pd.DataFrame(results, columns=[
    'contract', 'start_end', 'end_date',
    PerfStats.CAGR.value, 
    PerfStats.ANN_VOL.value,
    PerfStats.SHARPE.value,
    PerfStats.SKEWNESS.value,
]).set_index('contract')

# %%
result.shape
# Out:
# (168, 6)

# %% [markdown]
# # Performance summary
#
# This table displays contract information such as the contract name as well as performance statistics. Bar charts are superimposed for annualised returns and Sharpe ratios based on its value.   Statistics are in contracts' local currencies.
# Note that some start dates do not match the exact inception of the futures contract because of limited data availability.

# %%
(result
 .style.format({
        PerfStats.CAGR.value: "{:.1%}",
        PerfStats.ANN_VOL.value: "{:.1%}",
        PerfStats.SHARPE.value: "{:.2f}",
        PerfStats.SKEWNESS.value: "{:.2f}",
    })
 .bar(subset=PerfStats.CAGR.value)
 .bar(subset=PerfStats.SHARPE.value))
# Out:
# <style type="text/css">
# #T_f099d_row0_col2, #T_f099d_row83_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 86.3%, transparent 86.3%);
# }
# #T_f099d_row0_col4, #T_f099d_row46_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 77.4%, transparent 77.4%);
# }
# #T_f099d_row1_col2, #T_f099d_row33_col2, #T_f099d_row59_col2, #T_f099d_row62_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 81.0%, transparent 81.0%);
# }
# #T_f099d_row1_col4, #T_f099d_row76_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 61.5%, transparent 61.5%);
# }
# #T_f099d_row2_col2, #T_f099d_row53_col2, #T_f099d_row103_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 84.9%, transparent 84.9%);
# }
# #T_f099d_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 68.7%, transparent 68.7%);
# }
# #T_f099d_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 83.2%, transparent 83.2%);
# }
# #T_f099d_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 66.7%, transparent 66.7%);
# }
# #T_f099d_row4_col2, #T_f099d_row13_col2, #T_f099d_row20_col2, #T_f099d_row110_col2, #T_f099d_row154_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.2%, #d65f5f 79.2%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_f099d_row4_col4, #T_f099d_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.5%, #d65f5f 53.5%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row5_col2, #T_f099d_row120_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 85.2%, transparent 85.2%);
# }
# #T_f099d_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 68.6%, transparent 68.6%);
# }
# #T_f099d_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_f099d_row6_col4, #T_f099d_row49_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 57.7%, transparent 57.7%);
# }
# #T_f099d_row7_col2, #T_f099d_row10_col2, #T_f099d_row26_col2, #T_f099d_row112_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 79.5%, transparent 79.5%);
# }
# #T_f099d_row7_col4, #T_f099d_row93_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 54.6%, transparent 54.6%);
# }
# #T_f099d_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 82.1%, transparent 82.1%);
# }
# #T_f099d_row8_col4, #T_f099d_row51_col4, #T_f099d_row52_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 63.6%, transparent 63.6%);
# }
# #T_f099d_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 93.7%, transparent 93.7%);
# }
# #T_f099d_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 65.5%, transparent 65.5%);
# }
# #T_f099d_row10_col4, #T_f099d_row37_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 54.1%, transparent 54.1%);
# }
# #T_f099d_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.7%, #d65f5f 77.7%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_f099d_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, #d65f5f 49.8%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.2%, #d65f5f 78.2%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_f099d_row12_col4, #T_f099d_row65_col4, #T_f099d_row71_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.9%, #d65f5f 51.9%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row13_col4, #T_f099d_row160_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 52.8%, #d65f5f 52.8%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row14_col2, #T_f099d_row50_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 83.0%, transparent 83.0%);
# }
# #T_f099d_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 63.2%, transparent 63.2%);
# }
# #T_f099d_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 81.1%, transparent 81.1%);
# }
# #T_f099d_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 73.3%, transparent 73.3%);
# }
# #T_f099d_row16_col2, #T_f099d_row34_col2, #T_f099d_row106_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 83.5%, transparent 83.5%);
# }
# #T_f099d_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 79.8%, transparent 79.8%);
# }
# #T_f099d_row17_col2, #T_f099d_row22_col2, #T_f099d_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 81.4%, transparent 81.4%);
# }
# #T_f099d_row17_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 56.9%, transparent 56.9%);
# }
# #T_f099d_row18_col2, #T_f099d_row54_col2, #T_f099d_row115_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 84.1%, transparent 84.1%);
# }
# #T_f099d_row18_col4, #T_f099d_row162_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 61.3%, transparent 61.3%);
# }
# #T_f099d_row19_col2, #T_f099d_row40_col2, #T_f099d_row118_col2, #T_f099d_row121_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 81.3%, transparent 81.3%);
# }
# #T_f099d_row19_col4, #T_f099d_row56_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 76.7%, transparent 76.7%);
# }
# #T_f099d_row21_col2, #T_f099d_row23_col2, #T_f099d_row45_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 85.3%, transparent 85.3%);
# }
# #T_f099d_row21_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 69.5%, transparent 69.5%);
# }
# #T_f099d_row22_col4, #T_f099d_row97_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 64.7%, transparent 64.7%);
# }
# #T_f099d_row23_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 71.4%, transparent 71.4%);
# }
# #T_f099d_row24_col2, #T_f099d_row61_col2, #T_f099d_row71_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.1%, #d65f5f 78.1%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_f099d_row24_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.1%, #d65f5f 46.1%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row25_col2, #T_f099d_row160_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.8%, #d65f5f 78.8%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_f099d_row25_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.6%, #d65f5f 50.6%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_f099d_row26_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 83.4%, transparent 83.4%);
# }
# #T_f099d_row27_col2, #T_f099d_row95_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.3%, #d65f5f 79.3%, #d65f5f 84.8%, transparent 84.8%);
# }
# #T_f099d_row27_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f

# %%
fig, ax = plt.subplots(figsize=(8, 20))
ax.set_title("Long-only Sharpe ratio")
ax.set_ylabel("Sharpe ratio")
result[PerfStats.SHARPE.value].loc[::-1].plot(kind="barh", ax=ax, grid=True);  # reverse the plot order
ax.axvline(0, lw=1);

# %% [markdown]
# # Plot cumulative return series
#
# Here only the E-mini S&P 500 futures is shown as an example.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
engine = BacktestEngine(
    instrument='ES',
    strategy=Strategy.DELTA_ONE.value,
    log_level=logging.WARNING,
)
engine.run()
engine.calculate_equity_curve(calculate_net=False).plot(ax=ax, logy=True)
ax.set_ylabel('Cumulative returns');

# %%
print(f'Updated: {datetime.now(pytz.utc).strftime("%d-%b-%Y %H:%M")}')
# Out:
# Updated: 25-Jan-2026 13:46
