# %% [markdown]
# # Futures long-only performance summary
#
# This notebook summarises long-only performance statistics for major futures contracts provided by various data sources. Daily returns are computed by rolling the front contract before either the first notice day or the last trade day to avoid deliveries. Concretely, a daily return on a given day is written as follows:
#
# $$
# r_{t, i} = \frac{F_{t, i} - F_{t-1, t}}{F_{rolldate, i}}
# $$
#
# where $F_{t, i}$ is the futures price at time $t$ for an instrument $i$, $F_{rolldate, i}$ is the futures price when we roll into the contract. All functionalities as well as underlying data are provided by a private library `vivace`.

# %%
from datetime import datetime
import logging
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import pytz
import matplotlib.pyplot as plt
plt.style.use('bmh')

from vivace.backtest.contract import all_futures_lo_map
from vivace.backtest.engine import BacktestEngine
from vivace.backtest.stats import Performance, PerfStats
from vivace.enums import Strategy

# %% [markdown]
# `all_futures_lo_map` contains the list of all available futures contracts for long-only calculation.

# %%
all_futures_lo_map
# Out:
# ticker
# AC            MSCI World
# AD     Australian Dollar
# AE                   AEX
# AP               SPI 200
# B8     CZCE Ferrosilicon
#              ...
# YQ       DCE Coking Coal
# YY          DCE Iron Ore
# Z               FTSE 100
# ZB    New Zealand Dollar
# ZO                  Oats
# Name: name, Length: 168, dtype: object

# %% [markdown]
# Without any signals, `BacktestEngine` calculates simple long-only strategies by default. `Performance` computes typical performance metrics such as Sharpe ratio.

# %%
results = []

for ticker, name in all_futures_lo_map.items():
    engine = BacktestEngine(
        instrument=ticker,
        strategy=Strategy.DELTA_ONE.value,
        log_level=logging.WARNING,
    )
    engine.run()
    equity_curve = engine.calculate_equity_curve(calculate_net=False)
    stats = Performance(equity_curve).summary().squeeze()
    
    results.append([
        name,
        equity_curve.index[0].strftime('%d-%b-%Y'),
        equity_curve.index[-1].strftime('%d-%b-%Y'),
        stats[PerfStats.CAGR.value],
        stats[PerfStats.ANN_VOL.value],
        stats[PerfStats.SHARPE.value],
        stats[PerfStats.SKEWNESS.value],
    ])
    
result = pd.DataFrame(results, columns=[
    'contract', 'start_end', 'end_date',
    PerfStats.CAGR.value, 
    PerfStats.ANN_VOL.value,
    PerfStats.SHARPE.value,
    PerfStats.SKEWNESS.value,
]).set_index('contract')

# %%
result.shape
# Out:
# (168, 6)

# %% [markdown]
# # Performance summary
#
# This table displays contract information such as the contract name as well as performance statistics. Bar charts are superimposed for annualised returns and Sharpe ratios based on its value.   Statistics are in contracts' local currencies.
# Note that some start dates do not match the exact inception of the futures contract because of limited data availability.

# %%
(result
 .style.format({
        PerfStats.CAGR.value: "{:.1%}",
        PerfStats.ANN_VOL.value: "{:.1%}",
        PerfStats.SHARPE.value: "{:.2f}",
        PerfStats.SKEWNESS.value: "{:.2f}",
    })
 .bar(subset=PerfStats.CAGR.value)
 .bar(subset=PerfStats.SHARPE.value))
# Out:
# <style type="text/css">
# #T_95986_row0_col2, #T_95986_row132_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 85.0%, transparent 85.0%);
# }
# #T_95986_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 75.8%, transparent 75.8%);
# }
# #T_95986_row1_col2, #T_95986_row33_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 80.0%, transparent 80.0%);
# }
# #T_95986_row1_col4, #T_95986_row35_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 61.6%, transparent 61.6%);
# }
# #T_95986_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 83.9%, transparent 83.9%);
# }
# #T_95986_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 68.3%, transparent 68.3%);
# }
# #T_95986_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 82.1%, transparent 82.1%);
# }
# #T_95986_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 66.1%, transparent 66.1%);
# }
# #T_95986_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 79.0%, transparent 79.0%);
# }
# #T_95986_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 55.2%, transparent 55.2%);
# }
# #T_95986_row5_col2, #T_95986_row29_col2, #T_95986_row116_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 85.1%, transparent 85.1%);
# }
# #T_95986_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 70.4%, transparent 70.4%);
# }
# #T_95986_row6_col2, #T_95986_row40_col2, #T_95986_row118_col2, #T_95986_row121_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 80.3%, transparent 80.3%);
# }
# #T_95986_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 58.0%, transparent 58.0%);
# }
# #T_95986_row7_col2, #T_95986_row10_col2, #T_95986_row26_col2, #T_95986_row139_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 78.5%, transparent 78.5%);
# }
# #T_95986_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 54.9%, transparent 54.9%);
# }
# #T_95986_row8_col2, #T_95986_row36_col2, #T_95986_row76_col2, #T_95986_row127_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 81.3%, transparent 81.3%);
# }
# #T_95986_row8_col4, #T_95986_row106_col4, #T_95986_row115_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 63.9%, transparent 63.9%);
# }
# #T_95986_row9_col2, #T_95986_row109_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 92.8%, transparent 92.8%);
# }
# #T_95986_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 65.4%, transparent 65.4%);
# }
# #T_95986_row10_col4, #T_95986_row37_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 54.2%, transparent 54.2%);
# }
# #T_95986_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 76.7%, #d65f5f 76.7%, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_95986_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.9%, #d65f5f 49.9%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row12_col2, #T_95986_row142_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 76.8%, #d65f5f 76.8%, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_95986_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.1%, #d65f5f 51.1%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row13_col2, #T_95986_row20_col2, #T_95986_row65_col2, #T_95986_row110_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.3%, #d65f5f 78.3%, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_95986_row13_col4, #T_95986_row79_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.1%, #d65f5f 53.1%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 82.0%, transparent 82.0%);
# }
# #T_95986_row14_col4, #T_95986_row18_col4, #T_95986_row104_col4, #T_95986_row123_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 62.9%, transparent 62.9%);
# }
# #T_95986_row15_col2, #T_95986_row59_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 80.1%, transparent 80.1%);
# }
# #T_95986_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 73.2%, transparent 73.2%);
# }
# #T_95986_row16_col2, #T_95986_row72_col2, #T_95986_row77_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 82.5%, transparent 82.5%);
# }
# #T_95986_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 78.9%, transparent 78.9%);
# }
# #T_95986_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 80.6%, transparent 80.6%);
# }
# #T_95986_row17_col4, #T_95986_row145_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_95986_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 84.3%, transparent 84.3%);
# }
# #T_95986_row19_col2, #T_95986_row22_col2, #T_95986_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 80.4%, transparent 80.4%);
# }
# #T_95986_row19_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 76.7%, transparent 76.7%);
# }
# #T_95986_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.6%, #d65f5f 53.6%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row21_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 84.9%, transparent 84.9%);
# }
# #T_95986_row21_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 70.9%, transparent 70.9%);
# }
# #T_95986_row22_col4, #T_95986_row165_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 64.4%, transparent 64.4%);
# }
# #T_95986_row23_col2, #T_95986_row45_col2, #T_95986_row120_col2, #T_95986_row157_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65f5f 78.4%, #d65f5f 84.4%, transparent 84.4%);
# }
# #T_95986_row23_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 71.4%, transparent 71.4%);
# }
# #T_95986_row24_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.2%, #d65f5f 77.2%, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_95986_row24_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.4%, #d65f5f 46.4%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.9%, #d65f5f 77.9%, #d65f5f 78.4%, transparent 78.4%);
# }
# #T_95986_row25_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.0%, #d65f5f 51.0%, #d65f5f 53.9%, transparent 53.9%);
# }
# #T_95986_row26_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.9%, #d65f5f 53.9%, #d65f5f 83.5%, transparent 83.5%);
# }
# #T_95986_row27_col2, #T_95986_row95_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.4%, #d65

# %%
fig, ax = plt.subplots(figsize=(8, 20))
ax.set_title("Long-only Sharpe ratio")
ax.set_ylabel("Sharpe ratio")
result[PerfStats.SHARPE.value].loc[::-1].plot(kind="barh", ax=ax, grid=True);  # reverse the plot order
ax.axvline(0, lw=1);

# %% [markdown]
# # Plot cumulative return series
#
# Here only the E-mini S&P 500 futures is shown as an example.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
engine = BacktestEngine(
    instrument='ES',
    strategy=Strategy.DELTA_ONE.value,
    log_level=logging.WARNING,
)
engine.run()
engine.calculate_equity_curve(calculate_net=False).plot(ax=ax, logy=True)
ax.set_ylabel('Cumulative returns');

# %%
print(f'Updated: {datetime.now(pytz.utc).strftime("%d-%b-%Y %H:%M")}')
# Out:
# Updated: 24-Mar-2026 23:14
