# %% [markdown]
# # Futures long-only performance summary
#
# This notebook summarises long-only performance statistics for major futures contracts provided by various data sources. Daily returns are computed by rolling the front contract before either the first notice day or the last trade day to avoid deliveries. Concretely, a daily return on a given day is written as follows:
#
# $$
# r_{t, i} = \frac{F_{t, i} - F_{t-1, t}}{F_{rolldate, i}}
# $$
#
# where $F_{t, i}$ is the futures price at time $t$ for an instrument $i$, $F_{rolldate, i}$ is the futures price when we roll into the contract. All functionalities as well as underlying data are provided by a private library `vivace`.

# %%
from datetime import datetime
import logging
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import pytz
import matplotlib.pyplot as plt
plt.style.use('bmh')

from vivace.backtest.contract import all_futures_lo_map
from vivace.backtest.engine import BacktestEngine
from vivace.backtest.stats import Performance, PerfStats
from vivace.enums import Strategy

# %% [markdown]
# `all_futures_lo_map` contains the list of all available futures contracts for long-only calculation.

# %%
all_futures_lo_map
# Out:
# ticker
# AC            MSCI World
# AD     Australian Dollar
# AE                   AEX
# AP               SPI 200
# B8     CZCE Ferrosilicon
#              ...
# YQ       DCE Coking Coal
# YY          DCE Iron Ore
# Z               FTSE 100
# ZB    New Zealand Dollar
# ZO                  Oats
# Name: name, Length: 168, dtype: object

# %% [markdown]
# Without any signals, `BacktestEngine` calculates simple long-only strategies by default. `Performance` computes typical performance metrics such as Sharpe ratio.

# %%
results = []

for ticker, name in all_futures_lo_map.items():
    engine = BacktestEngine(
        instrument=ticker,
        strategy=Strategy.DELTA_ONE.value,
        log_level=logging.WARNING,
    )
    engine.run()
    equity_curve = engine.calculate_equity_curve(calculate_net=False)
    stats = Performance(equity_curve).summary().squeeze()
    
    results.append([
        name,
        equity_curve.index[0].strftime('%d-%b-%Y'),
        equity_curve.index[-1].strftime('%d-%b-%Y'),
        stats[PerfStats.CAGR.value],
        stats[PerfStats.ANN_VOL.value],
        stats[PerfStats.SHARPE.value],
        stats[PerfStats.SKEWNESS.value],
    ])
    
result = pd.DataFrame(results, columns=[
    'contract', 'start_end', 'end_date',
    PerfStats.CAGR.value, 
    PerfStats.ANN_VOL.value,
    PerfStats.SHARPE.value,
    PerfStats.SKEWNESS.value,
]).set_index('contract')

# %%
result.shape
# Out:
# (168, 6)

# %% [markdown]
# # Performance summary
#
# This table displays contract information such as the contract name as well as performance statistics. Bar charts are superimposed for annualised returns and Sharpe ratios based on its value.   Statistics are in contracts' local currencies.
# Note that some start dates do not match the exact inception of the futures contract because of limited data availability.

# %%
(result
 .style.format({
        PerfStats.CAGR.value: "{:.1%}",
        PerfStats.ANN_VOL.value: "{:.1%}",
        PerfStats.SHARPE.value: "{:.2f}",
        PerfStats.SKEWNESS.value: "{:.2f}",
    })
 .bar(subset=PerfStats.CAGR.value)
 .bar(subset=PerfStats.SHARPE.value))
# Out:
# <style type="text/css">
# #T_da6f6_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 86.2%, transparent 86.2%);
# }
# #T_da6f6_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 77.6%, transparent 77.6%);
# }
# #T_da6f6_row1_col2, #T_da6f6_row33_col2, #T_da6f6_row59_col2, #T_da6f6_row72_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 80.8%, transparent 80.8%);
# }
# #T_da6f6_row1_col4, #T_da6f6_row18_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 61.5%, transparent 61.5%);
# }
# #T_da6f6_row2_col2, #T_da6f6_row21_col2, #T_da6f6_row103_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 84.8%, transparent 84.8%);
# }
# #T_da6f6_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 68.8%, transparent 68.8%);
# }
# #T_da6f6_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 83.1%, transparent 83.1%);
# }
# #T_da6f6_row3_col4, #T_da6f6_row120_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 66.8%, transparent 66.8%);
# }
# #T_da6f6_row4_col2, #T_da6f6_row87_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.9%, #d65f5f 78.9%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.4%, #d65f5f 53.4%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 85.0%, transparent 85.0%);
# }
# #T_da6f6_row5_col4, #T_da6f6_row34_col4, #T_da6f6_row150_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_da6f6_row6_col2, #T_da6f6_row40_col2, #T_da6f6_row121_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.1%, transparent 81.1%);
# }
# #T_da6f6_row6_col4, #T_da6f6_row141_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 57.9%, transparent 57.9%);
# }
# #T_da6f6_row7_col2, #T_da6f6_row26_col2, #T_da6f6_row112_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_da6f6_row7_col4, #T_da6f6_row112_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 54.8%, transparent 54.8%);
# }
# #T_da6f6_row8_col2, #T_da6f6_row74_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 82.1%, transparent 82.1%);
# }
# #T_da6f6_row8_col4, #T_da6f6_row115_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 63.8%, transparent 63.8%);
# }
# #T_da6f6_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 93.6%, transparent 93.6%);
# }
# #T_da6f6_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 65.5%, transparent 65.5%);
# }
# #T_da6f6_row10_col2, #T_da6f6_row42_col2, #T_da6f6_row114_col2, #T_da6f6_row139_col2, #T_da6f6_row145_col2, #T_da6f6_row162_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.5%, transparent 79.5%);
# }
# #T_da6f6_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 54.6%, transparent 54.6%);
# }
# #T_da6f6_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.5%, #d65f5f 77.5%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.9%, #d65f5f 49.9%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row12_col2, #T_da6f6_row24_col2, #T_da6f6_row61_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 77.9%, #d65f5f 77.9%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.6%, #d65f5f 51.6%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row13_col2, #T_da6f6_row65_col2, #T_da6f6_row110_col2, #T_da6f6_row159_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row13_col4, #T_da6f6_row91_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.1%, #d65f5f 53.1%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row14_col2, #T_da6f6_row50_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 82.9%, transparent 82.9%);
# }
# #T_da6f6_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 63.4%, transparent 63.4%);
# }
# #T_da6f6_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 80.9%, transparent 80.9%);
# }
# #T_da6f6_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 73.4%, transparent 73.4%);
# }
# #T_da6f6_row16_col2, #T_da6f6_row106_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 83.3%, transparent 83.3%);
# }
# #T_da6f6_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 79.0%, transparent 79.0%);
# }
# #T_da6f6_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.4%, transparent 81.4%);
# }
# #T_da6f6_row17_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_da6f6_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 84.1%, transparent 84.1%);
# }
# #T_da6f6_row19_col2, #T_da6f6_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_da6f6_row19_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 76.7%, transparent 76.7%);
# }
# #T_da6f6_row20_col2, #T_da6f6_row91_col2, #T_da6f6_row154_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.0%, #d65f5f 79.0%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.5%, #d65f5f 53.5%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row21_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 68.7%, transparent 68.7%);
# }
# #T_da6f6_row22_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 64.4%, transparent 64.4%);
# }
# #T_da6f6_row23_col2, #T_da6f6_row120_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 85.1%, transparent 85.1%);
# }
# #T_da6f6_row23_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 71.4%, transparent 71.4%);
# }
# #T_da6f6_row24_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 46.1%, #d65f5f 46.1%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row25_col2, #T_da6f6_row78_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 78.6%, #d65f5f 78.6%, #d65f5f 79.1%, transparent 79.1%);
# }
# #T_da6f6_row25_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.9%, #d65f5f 50.9%, #d65f5f 53.8%, transparent 53.8%);
# }
# #T_da6f6_row26_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 53.8%, #d65f5f 53.8%, #d65f5f 83.4%, transparent 83.4%);
# }
# #T_da6f6_row27_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 79.1%, #d65f5f 79.1%, #d65f5f 84

# %%
fig, ax = plt.subplots(figsize=(8, 20))
ax.set_title("Long-only Sharpe ratio")
ax.set_ylabel("Sharpe ratio")
result[PerfStats.SHARPE.value].loc[::-1].plot(kind="barh", ax=ax, grid=True);  # reverse the plot order
ax.axvline(0, lw=1);

# %% [markdown]
# # Plot cumulative return series
#
# Here only the E-mini S&P 500 futures is shown as an example.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
engine = BacktestEngine(
    instrument='ES',
    strategy=Strategy.DELTA_ONE.value,
    log_level=logging.WARNING,
)
engine.run()
engine.calculate_equity_curve(calculate_net=False).plot(ax=ax, logy=True)
ax.set_ylabel('Cumulative returns');

# %%
print(f'Updated: {datetime.now(pytz.utc).strftime("%d-%b-%Y %H:%M")}')
# Out:
# Updated: 12-Feb-2026 23:23
